# %% [markdown]
# # Pandas Assignment: 50 Basic Questions
#
# Dataset Columns: CID, TID, Gender, Age Group, Purchase Date, Product Category, Discount Availed, Discount Name, Discount Amount (INR), Gross Amount, Net Amount, Purchase Method, Location

# %% [markdown]
# ### 1. Load the CSV file into a Pandas DataFrame.

# %%
import pandas as pd

df = pd.read_csv("FILE:///A:/Big Data JOBJACK/python_tut/datasets/Retail_Purchase_Dataset.csv")

df
# Out:
#           CID         TID  Gender     Age Group        Purchase Date  \
# 0      943146  5876328741  Female         25-45  30/08/2023 20:27:08
# 1      180079  1018503182    Male         25-45  23/02/2024 09:33:46
# 2      337580  3814082218   Other  60 and above  06/03/2022 09:09:50
# 3      180333  1395204173   Other  60 and above  04/11/2020 04:41:57
# 4      447553  8009390577    Male         18-25  31/05/2022 17:00:32
# ...       ...         ...     ...           ...                  ...
# 54995  295864  5407639888   Other         25-45  23/02/2020 10:42:04
# 54996  706435  1144029904   Other         18-25  12/07/2021 15:59:21
# 54997  649435  9587323189    Male         45-60  02/08/2024 09:30:44
# 54998  982183  5032564481  Female         45-60  05/08/2020 23:57:56
# 54999  126691  9172953722    Male         25-45  21/07/2022 09:05:18
#
#         Product Category Discount Availed    Discount Name  \
# 0            Electronics              Yes        FESTIVE50
# ...

# %% [markdown]
# ### 2. Display the first 5 rows.

# %%
df.head(5)
# Out:
#       CID         TID  Gender     Age Group        Purchase Date  \
# 0  943146  5876328741  Female         25-45  30/08/2023 20:27:08
# 1  180079  1018503182    Male         25-45  23/02/2024 09:33:46
# 2  337580  3814082218   Other  60 and above  06/03/2022 09:09:50
# 3  180333  1395204173   Other  60 and above  04/11/2020 04:41:57
# 4  447553  8009390577    Male         18-25  31/05/2022 17:00:32
#
#    Product Category Discount Availed    Discount Name  Discount Amount (INR)  \
# 0       Electronics              Yes        FESTIVE50                  64.30
# 1       Electronics              Yes  SEASONALOFFER21                 175.19
# 2          Clothing              Yes  SEASONALOFFER21                 211.54
# 3  Sports & Fitness               No              NaN                   0.00
# 4  Sports & Fitness              Yes         WELCOME5                 439.92
#
#    Gross Amount   Net Amount Purchase Method   Location
# ...

# %% [markdown]
# ### 3. Display the last 5 rows.

# %%
df.tail(5)
# Out:
#           CID         TID  Gender Age Group        Purchase Date  \
# 54995  295864  5407639888   Other     25-45  23/02/2020 10:42:04
# 54996  706435  1144029904   Other     18-25  12/07/2021 15:59:21
# 54997  649435  9587323189    Male     45-60  02/08/2024 09:30:44
# 54998  982183  5032564481  Female     45-60  05/08/2020 23:57:56
# 54999  126691  9172953722    Male     25-45  21/07/2022 09:05:18
#
#         Product Category Discount Availed    Discount Name  \
# 54995        Electronics              Yes  SEASONALOFFER21
# 54996        Electronics              Yes  SEASONALOFFER21
# 54997     Home & Kitchen              Yes         NEWYEARS
# 54998  Beauty and Health              Yes  SEASONALOFFER21
# 54999  Beauty and Health              Yes         NEWYEARS
#
#        Discount Amount (INR)  Gross Amount  Net Amount   Purchase Method  \
# 54995                 110.89     2819.9073   2709.0173        Debit Card
# ...

# %% [markdown]
# ### 4. Print the shape of the DataFrame.

# %%
df.shape
# Out:
# (55000, 13)

# %% [markdown]
# ### 5. Show all column names.

# %%
list(df.columns)
# Out:
# ['CID',
#  'TID',
#  'Gender',
#  'Age Group',
#  'Purchase Date',
#  'Product Category',
#  'Discount Availed',
#  'Discount Name',
#  'Discount Amount (INR)',
#  'Gross Amount',
#  'Net Amount',
#  'Purchase Method',
#  'Location']

# %% [markdown]
# ### 6. Display the data types of each column.

# %%
df.dtypes
# Out:
# CID                        int64
# TID                        int64
# Gender                    object
# Age Group                 object
# Purchase Date             object
# Product Category          object
# Discount Availed          object
# Discount Name             object
# Discount Amount (INR)    float64
# Gross Amount             float64
# Net Amount               float64
# Purchase Method           object
# Location                  object
# dtype: object

# %% [markdown]
# ### 7. Check for missing values in each column.

# %%
df.isna().sum()
# Out:
# CID                          0
# TID                          0
# Gender                       0
# Age Group                    0
# Purchase Date                0
# Product Category             0
# Discount Availed             0
# Discount Name            27585
# Discount Amount (INR)        0
# Gross Amount                 0
# Net Amount                   0
# Purchase Method              0
# Location                     0
# dtype: int64

# %% [markdown]
# ### 8. Count total missing values in the dataset.

# %%
df.isna().sum().sum()
# Out:
# np.int64(27585)

# %% [markdown]
# ### 9. Show summary statistics for numeric columns.

# %%
df.describe()
# Out:
#                  CID           TID  Discount Amount (INR)  Gross Amount  \
# count   55000.000000  5.500000e+04           55000.000000  55000.000000
# mean   551245.593891  5.504740e+09             136.986796   3012.936606
# std    260603.330337  2.594534e+09             165.375502   1718.431066
# min    100009.000000  1.000163e+09               0.000000    136.454325
# 25%    323717.000000  3.252604e+09               0.000000   1562.111325
# 50%    550088.500000  5.498383e+09               0.000000   2954.266150
# 75%    776955.750000  7.747933e+09             274.115000   4342.221675
# max    999996.000000  9.999393e+09             500.000000   8394.825600
#
#          Net Amount
# count  55000.000000
# mean    2875.949810
# std     1726.127778
# min     -351.119775
# 25%     1429.551863
# 50%     2814.910875
# 75%     4211.407838
# max     8394.825600

# %% [markdown]
# ### 10. Display info about the DataFrame using .info().

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55000 entries, 0 to 54999
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CID                    55000 non-null  int64
#  1   TID                    55000 non-null  int64
#  2   Gender                 55000 non-null  object
#  3   Age Group              55000 non-null  object
#  4   Purchase Date          55000 non-null  object
#  5   Product Category       55000 non-null  object
#  6   Discount Availed       55000 non-null  object
#  7   Discount Name          27415 non-null  object
#  8   Discount Amount (INR)  55000 non-null  float64
#  9   Gross Amount           55000 non-null  float64
#  10  Net Amount             55000 non-null  float64
#  11  Purchase Method        55000 non-null  object
#  12  Location               55000 non-null  object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 5.5+ MB

# %% [markdown]
# ### 11. Select the CID and TID columns.

# %%
cid_tid_df = df[['CID','TID']]
cid_tid_df
# Out:
#           CID         TID
# 0      943146  5876328741
# 1      180079  1018503182
# 2      337580  3814082218
# 3      180333  1395204173
# 4      447553  8009390577
# ...       ...         ...
# 54995  295864  5407639888
# 54996  706435  1144029904
# 54997  649435  9587323189
# 54998  982183  5032564481
# 54999  126691  9172953722
#
# [55000 rows x 2 columns]

# %% [markdown]
# ### 12. Display the first 10 rows of Gender and Age Group.

# %%
df[['Gender','Age Group']].head(10)
# Out:
#    Gender     Age Group
# 0  Female         25-45
# 1    Male         25-45
# 2   Other  60 and above
# 3   Other  60 and above
# 4    Male         18-25
# 5    Male         18-25
# 6    Male         25-45
# 7  Female         18-25
# 8    Male         18-25
# 9   Other  60 and above

# %% [markdown]
# ### 13. Filter rows where Gender is 'Male'.

# %%
df[df['Gender']=='Male']
# Out:
#           CID         TID Gender Age Group        Purchase Date  \
# 1      180079  1018503182   Male     25-45  23/02/2024 09:33:46
# 4      447553  8009390577   Male     18-25  31/05/2022 17:00:32
# 5      200614  3994452858   Male     18-25  12/07/2021 15:10:27
# 6      668787  9460023916   Male     25-45  08/10/2023 16:59:52
# 8      414167  2841266620   Male     18-25  29/04/2020 09:10:46
# ...       ...         ...    ...       ...                  ...
# 54989  812597  3862962312   Male     45-60  07/08/2022 11:42:13
# 54990  180783  4001403523   Male     25-45  06/08/2024 23:15:21
# 54992  639165  8525877571   Male     25-45  15/05/2022 20:32:26
# 54997  649435  9587323189   Male     45-60  02/08/2024 09:30:44
# 54999  126691  9172953722   Male     25-45  21/07/2022 09:05:18
#
#         Product Category Discount Availed    Discount Name  \
# 1            Electronics              Yes  SEASONALOFFER21
# 4       Sports & Fitness              Yes         WELCOME5
# ...

# %% [markdown]
# ### 14. Filter rows where Age Group is '26-35'.

# %%
df[df['Age Group'] == "26-35"]
# Out:
# Empty DataFrame
# Columns: [CID, TID, Gender, Age Group, Purchase Date, Product Category, Discount Availed, Discount Name, Discount Amount (INR), Gross Amount, Net Amount, Purchase Method, Location]
# Index: []

# %% [markdown]
# ### 15. Filter rows where Discount Availed is 'Yes'.

# %%
df[df['Discount Availed']=='Yes']
# Out:
#           CID         TID  Gender     Age Group        Purchase Date  \
# 0      943146  5876328741  Female         25-45  30/08/2023 20:27:08
# 1      180079  1018503182    Male         25-45  23/02/2024 09:33:46
# 2      337580  3814082218   Other  60 and above  06/03/2022 09:09:50
# 4      447553  8009390577    Male         18-25  31/05/2022 17:00:32
# 5      200614  3994452858    Male         18-25  12/07/2021 15:10:27
# ...       ...         ...     ...           ...                  ...
# 54995  295864  5407639888   Other         25-45  23/02/2020 10:42:04
# 54996  706435  1144029904   Other         18-25  12/07/2021 15:59:21
# 54997  649435  9587323189    Male         45-60  02/08/2024 09:30:44
# 54998  982183  5032564481  Female         45-60  05/08/2020 23:57:56
# 54999  126691  9172953722    Male         25-45  21/07/2022 09:05:18
#
#         Product Category Discount Availed    Discount Name  \
# 0            Electronics              Yes        FESTIVE50
# ...

# %% [markdown]
# ### 16. Filter rows where Discount Amount (INR) > 500.

# %%
df[df['Discount Amount (INR)'] > 500]
# Out:
# Empty DataFrame
# Columns: [CID, TID, Gender, Age Group, Purchase Date, Product Category, Discount Availed, Discount Name, Discount Amount (INR), Gross Amount, Net Amount, Purchase Method, Location]
# Index: []

# %% [markdown]
# ### 17. Filter rows where Product Category is 'Electronics'.

# %%
df[df['Product Category'] == 'Electronics']
# Out:
#           CID         TID  Gender Age Group        Purchase Date  \
# 0      943146  5876328741  Female     25-45  30/08/2023 20:27:08
# 1      180079  1018503182    Male     25-45  23/02/2024 09:33:46
# 6      668787  9460023916    Male     25-45  08/10/2023 16:59:52
# 7      933551  6877673032  Female     18-25  14/12/2022 20:13:45
# 11     629298  2229511931   Other     45-60  02/11/2021 15:37:38
# ...       ...         ...     ...       ...                  ...
# 54985  903683  2516034122  Female     25-45  22/03/2024 23:52:20
# 54987  907365  2841576857    Male     25-45  12/05/2023 15:48:26
# 54992  639165  8525877571    Male     25-45  15/05/2022 20:32:26
# 54995  295864  5407639888   Other     25-45  23/02/2020 10:42:04
# 54996  706435  1144029904   Other     18-25  12/07/2021 15:59:21
#
#       Product Category Discount Availed    Discount Name  \
# 0          Electronics              Yes        FESTIVE50
# 1          Electronics              Yes  SEASONALOFFER21
# ...

# %% [markdown]
# ### 18. Display rows where Purchase Method is 'Credit Card'.

# %%
df[df['Purchase Method']=='Credit Card']
# Out:
#           CID         TID  Gender     Age Group        Purchase Date  \
# 0      943146  5876328741  Female         25-45  30/08/2023 20:27:08
# 1      180079  1018503182    Male         25-45  23/02/2024 09:33:46
# 2      337580  3814082218   Other  60 and above  06/03/2022 09:09:50
# 4      447553  8009390577    Male         18-25  31/05/2022 17:00:32
# 5      200614  3994452858    Male         18-25  12/07/2021 15:10:27
# ...       ...         ...     ...           ...                  ...
# 54991  103234  5584476454   Other         45-60  29/08/2021 18:47:25
# 54992  639165  8525877571    Male         25-45  15/05/2022 20:32:26
# 54997  649435  9587323189    Male         45-60  02/08/2024 09:30:44
# 54998  982183  5032564481  Female         45-60  05/08/2020 23:57:56
# 54999  126691  9172953722    Male         25-45  21/07/2022 09:05:18
#
#         Product Category Discount Availed    Discount Name  \
# 0            Electronics              Yes        FESTIVE50
# ...

# %% [markdown]
# ### 19. Select rows where Location is 'Mumbai'.

# %%
df[df['Location']=='Mumbai']
# Out:
#           CID         TID  Gender     Age Group        Purchase Date  \
# 19     787512  9582806381    Male         18-25  17/03/2021 17:32:46
# 20     538174  1322344974    Male  60 and above  24/11/2020 02:42:48
# 22     443120  4473452038  Female      under 18  07/09/2023 23:23:03
# 24     745014  9202622469    Male         18-25  04/05/2023 18:06:02
# 26     654718  6758404906   Other      under 18  22/07/2023 23:26:04
# ...       ...         ...     ...           ...                  ...
# 54983  306954  1846818218  Female         18-25  13/09/2023 06:55:26
# 54985  903683  2516034122  Female         25-45  22/03/2024 23:52:20
# 54986  915197  5506311767  Female         25-45  06/03/2023 15:57:05
# 54997  649435  9587323189    Male         45-60  02/08/2024 09:30:44
# 54999  126691  9172953722    Male         25-45  21/07/2022 09:05:18
#
#         Product Category Discount Availed    Discount Name  \
# 19                 Books               No              NaN
# ...

# %% [markdown]
# ### 20. Select rows where Gross Amount is between 1000 and 5000.

# %%
df[df['Gross Amount'].between(1000,5000)]
# Out:
#           CID         TID  Gender     Age Group        Purchase Date  \
# 1      180079  1018503182    Male         25-45  23/02/2024 09:33:46
# 2      337580  3814082218   Other  60 and above  06/03/2022 09:09:50
# 4      447553  8009390577    Male         18-25  31/05/2022 17:00:32
# 5      200614  3994452858    Male         18-25  12/07/2021 15:10:27
# 7      933551  6877673032  Female         18-25  14/12/2022 20:13:45
# ...       ...         ...     ...           ...                  ...
# 54995  295864  5407639888   Other         25-45  23/02/2020 10:42:04
# 54996  706435  1144029904   Other         18-25  12/07/2021 15:59:21
# 54997  649435  9587323189    Male         45-60  02/08/2024 09:30:44
# 54998  982183  5032564481  Female         45-60  05/08/2020 23:57:56
# 54999  126691  9172953722    Male         25-45  21/07/2022 09:05:18
#
#         Product Category Discount Availed    Discount Name  \
# 1            Electronics              Yes  SEASONALOFFER21
# ...

# %% [markdown]
# ### 21. Sort the DataFrame by Gross Amount ascending.

# %%
df.sort_values(by='Gross Amount', ascending=True)
# Out:
#           CID         TID  Gender Age Group        Purchase Date  \
# 37352  570046  1964089589  Female     25-45  18/02/2020 02:14:13
# 17568  262070  5537538360  Female  under 18  01/02/2020 00:15:47
# 38606  481252  9891577351  Female     25-45  03/02/2020 07:18:59
# 40677  376537  8659700479  Female     25-45  14/01/2020 19:49:31
# 48164  386840  8029271119  Female     18-25  20/02/2020 14:18:22
# ...       ...         ...     ...       ...                  ...
# 52533  675956  7090926391  Female  under 18  01/12/2023 07:55:47
# 5521   255607  7392860072    Male     18-25  15/12/2023 15:55:16
# 29249  871976  7829441574  Female     25-45  19/12/2023 09:49:50
# 21848  738513  7204773289  Female     18-25  06/12/2023 04:26:33
# 26874  202767  5202191880   Other     18-25  11/12/2023 11:19:48
#
#         Product Category Discount Availed    Discount Name  \
# 37352  Beauty and Health               No              NaN
# 17568        Electronics              Yes         NEWYEARS
# ...

# %% [markdown]
# ### 22. Sort the DataFrame by Net Amount descending.

# %%
df.sort_values(by='Net Amount', ascending=False)
# Out:
#           CID         TID  Gender Age Group        Purchase Date  \
# 26874  202767  5202191880   Other     18-25  11/12/2023 11:19:48
# 21848  738513  7204773289  Female     18-25  06/12/2023 04:26:33
# 5521   255607  7392860072    Male     18-25  15/12/2023 15:55:16
# 46212  327575  7133917620   Other  under 18  02/12/2023 07:47:56
# 27657  433217  1340357202    Male     45-60  21/12/2023 12:16:26
# ...       ...         ...     ...       ...                  ...
# 16031  574966  9576162844  Female     25-45  30/01/2023 00:53:06
# 2606   472724  2853800882   Other     18-25  03/04/2020 16:08:07
# 22138  761286  3119749374    Male     45-60  15/06/2022 12:08:59
# 7152   717101  8220478366    Male     25-45  10/02/2022 22:38:06
# 18827  898531  4861274119   Other     45-60  23/02/2020 05:26:39
#
#         Product Category Discount Availed    Discount Name  \
# 26874     Home & Kitchen               No              NaN
# 21848  Beauty and Health               No              NaN
# ...

# %% [markdown]
# ### 23. Sort by Location and then by Purchase Date.

# %%
df.sort_values(by=['Location','Purchase Date'],ascending=[True,True])
# Out:
#           CID         TID  Gender     Age Group        Purchase Date  \
# 14677  356972  9481824682  Female         25-45  01/01/2020 16:36:35
# 52154  291523  3456432695   Other         25-45  01/01/2020 19:55:04
# 36766  636294  8503669581  Female         25-45  01/01/2021 10:36:31
# 47676  582716  7455858410   Other         25-45  01/01/2022 03:01:35
# 26695  380678  4378851841    Male         25-45  01/01/2022 07:47:24
# ...       ...         ...     ...           ...                  ...
# 8966   298020  1127367408    Male         25-45  31/08/2023 16:58:41
# 4011   502349  3964650442  Female         18-25  31/08/2024 03:59:17
# 24671  374505  8692673674  Female         25-45  31/08/2024 11:51:32
# 50120  486244  2152632978  Female         25-45  31/10/2019 13:34:58
# 48865  502580  6251204383    Male  60 and above  31/12/2023 09:50:47
#
#         Product Category Discount Availed    Discount Name  \
# 14677              Books              Yes           SAVE10
# ...

# %% [markdown]
# ### 24. Find the number of unique locations.

# %%
df['Location'].nunique()
# Out:
# 14

# %% [markdown]
# ### 25. Display all unique locations.

# %%
list(df['Location'].unique())
# Out:
# ['Ahmedabad',
#  'Bangalore',
#  'Delhi',
#  'Other',
#  'Chennai',
#  'Dehradun',
#  'Pune',
#  'Hyderabad',
#  'Mumbai',
#  'Jaipur',
#  'Lucknow',
#  'Kolkata',
#  'Srinagar',
#  'Varanasi']

# %% [markdown]
# ### 26. Find the number of unique product categories.

# %%
df['Product Category'].nunique()
# Out:
# 9

# %% [markdown]
# ### 27. Display the top 10 most frequent product categories.

# %%
df['Product Category'].value_counts().head(10)
# Out:
# Product Category
# Electronics          16574
# Clothing             10968
# Beauty and Health     8332
# Sports & Fitness      5557
# Home & Kitchen        5489
# Books                 2762
# Other                 2171
# Pet Care              1618
# Toys & Games          1529
# Name: count, dtype: int64

# %% [markdown]
# ### 28. Display the top 10 most frequent locations.

# %%
df['Location'].value_counts().head(10)
# Out:
# Location
# Mumbai       11197
# Delhi        10799
# Bangalore     8249
# Hyderabad     5545
# Chennai       4368
# Pune          3781
# Ahmedabad     2785
# Kolkata       2709
# Jaipur        1678
# Lucknow       1136
# Name: count, dtype: int64

# %% [markdown]
# ### 29. Find the transaction with the highest Gross Amount.

# %%
df.loc[df['Gross Amount'].idxmax(),'TID']
# Out:
# np.int64(5202191880)

# %% [markdown]
# ### 30. Find the transaction with the highest Discount Amount (INR).

# %%
df.loc[df['Discount Amount (INR)'].idxmax(),'TID']
# Out:
# np.int64(8375499682)

# %% [markdown]
# ### 31. Create a new column Discount Percentage = (Discount Amount / Gross Amount) * 100.

# %%
df['Discount Percentage'] = (df['Discount Amount (INR)'] / df['Gross Amount']) * 100

df.head(5)
# Out:
#       CID         TID  Gender     Age Group        Purchase Date  \
# 0  943146  5876328741  Female         25-45  30/08/2023 20:27:08
# 1  180079  1018503182    Male         25-45  23/02/2024 09:33:46
# 2  337580  3814082218   Other  60 and above  06/03/2022 09:09:50
# 3  180333  1395204173   Other  60 and above  04/11/2020 04:41:57
# 4  447553  8009390577    Male         18-25  31/05/2022 17:00:32
#
#    Product Category Discount Availed    Discount Name  Discount Amount (INR)  \
# 0       Electronics              Yes        FESTIVE50                  64.30
# 1       Electronics              Yes  SEASONALOFFER21                 175.19
# 2          Clothing              Yes  SEASONALOFFER21                 211.54
# 3  Sports & Fitness               No      No Discount                   0.00
# 4  Sports & Fitness              Yes         WELCOME5                 439.92
#
#    Gross Amount   Net Amount Purchase Method   Location  Discount Percentage
# ...

# %% [markdown]
# ### 32. Round Discount Percentage to 2 decimal places.

# %%
df[['Discount Percentage']].round(2)
# Out:
#        Discount Percentage
# 0                     8.87
# 1                     3.78
# 2                    10.65
# 3                     0.00
# 4                    19.19
# ...                    ...
# 54995                 3.93
# 54996                12.56
# 54997                10.20
# 54998                 5.14
# 54999                10.28
#
# [55000 rows x 1 columns]

# %% [markdown]
# ### 33. Convert Product Category to uppercase.

# %%
df['Product Category']  = df['Product Category'].str.upper()
df[['Product Category']]
# Out:
#         Product Category
# 0            ELECTRONICS
# 1            ELECTRONICS
# 2               CLOTHING
# 3       SPORTS & FITNESS
# 4       SPORTS & FITNESS
# ...                  ...
# 54995        ELECTRONICS
# 54996        ELECTRONICS
# 54997     HOME & KITCHEN
# 54998  BEAUTY AND HEALTH
# 54999  BEAUTY AND HEALTH
#
# [55000 rows x 1 columns]

# %% [markdown]
# ### 34. Remove leading/trailing spaces from Discount Name.

# %%
df['Discount Name'].str.strip()
# Out:
# 0              FESTIVE50
# 1        SEASONALOFFER21
# 2        SEASONALOFFER21
# 3                    NaN
# 4               WELCOME5
#               ...
# 54995    SEASONALOFFER21
# 54996    SEASONALOFFER21
# 54997           NEWYEARS
# 54998    SEASONALOFFER21
# 54999           NEWYEARS
# Name: Discount Name, Length: 55000, dtype: object

# %% [markdown]
# ### 35. Replace missing Discount Name with 'No Discount'.

# %%
df['Discount Name'].fillna("No Discount",inplace=True)
df
# Out:
#           CID         TID  Gender     Age Group        Purchase Date  \
# 0      943146  5876328741  Female         25-45  30/08/2023 20:27:08
# 1      180079  1018503182    Male         25-45  23/02/2024 09:33:46
# 2      337580  3814082218   Other  60 and above  06/03/2022 09:09:50
# 3      180333  1395204173   Other  60 and above  04/11/2020 04:41:57
# 4      447553  8009390577    Male         18-25  31/05/2022 17:00:32
# ...       ...         ...     ...           ...                  ...
# 54995  295864  5407639888   Other         25-45  23/02/2020 10:42:04
# 54996  706435  1144029904   Other         18-25  12/07/2021 15:59:21
# 54997  649435  9587323189    Male         45-60  02/08/2024 09:30:44
# 54998  982183  5032564481  Female         45-60  05/08/2020 23:57:56
# 54999  126691  9172953722    Male         25-45  21/07/2022 09:05:18
#
#         Product Category Discount Availed    Discount Name  \
# 0            Electronics              Yes        FESTIVE50
# ...

# %% [markdown]
# ### 36. Drop the Discount Availed column.

# %%
df.columns
# Out:
# Index(['CID', 'TID', 'Gender', 'Age Group', 'Purchase Date',
#        'Product Category', 'Discount Availed', 'Discount Name',
#        'Discount Amount (INR)', 'Gross Amount', 'Net Amount',
#        'Purchase Method', 'Location'],
#       dtype='object')

# %%
df.drop(columns=['Discount Availed'],inplace=True)

# %% [markdown]
# ### 37. Rename Purchase Method column to PaymentMethod.

# %%
df.rename(columns={'Purchase Method':'PaymentMethod'},inplace=True)
df
# Out:
#           CID         TID  Gender     Age Group        Purchase Date  \
# 0      943146  5876328741  Female         25-45  30/08/2023 20:27:08
# 1      180079  1018503182    Male         25-45  23/02/2024 09:33:46
# 2      337580  3814082218   Other  60 and above  06/03/2022 09:09:50
# 3      180333  1395204173   Other  60 and above  04/11/2020 04:41:57
# 4      447553  8009390577    Male         18-25  31/05/2022 17:00:32
# ...       ...         ...     ...           ...                  ...
# 54995  295864  5407639888   Other         25-45  23/02/2020 10:42:04
# 54996  706435  1144029904   Other         18-25  12/07/2021 15:59:21
# 54997  649435  9587323189    Male         45-60  02/08/2024 09:30:44
# 54998  982183  5032564481  Female         45-60  05/08/2020 23:57:56
# 54999  126691  9172953722    Male         25-45  21/07/2022 09:05:18
#
#         Product Category    Discount Name  Discount Amount (INR)  \
# 0            Electronics        FESTIVE50                  64.30
# ...

# %% [markdown]
# ### 38. Reorder columns so CID and TID come first.

# %%
df = df[['CID','TID'] + list(df.columns.drop(['CID','TID']))]
df
# Out:
#           CID         TID  Gender     Age Group       Purchase Date  \
# 0      943146  5876328741  Female         25-45 2023-08-30 20:27:08
# 1      180079  1018503182    Male         25-45 2024-02-23 09:33:46
# 2      337580  3814082218   Other  60 and above 2022-03-06 09:09:50
# 3      180333  1395204173   Other  60 and above 2020-11-04 04:41:57
# 4      447553  8009390577    Male         18-25 2022-05-31 17:00:32
# ...       ...         ...     ...           ...                 ...
# 54995  295864  5407639888   Other         25-45 2020-02-23 10:42:04
# 54996  706435  1144029904   Other         18-25 2021-07-12 15:59:21
# 54997  649435  9587323189    Male         45-60 2024-08-02 09:30:44
# 54998  982183  5032564481  Female         45-60 2020-08-05 23:57:56
# 54999  126691  9172953722    Male         25-45 2022-07-21 09:05:18
#
#         Product Category    Discount Name  Discount Amount (INR)  \
# 0            Electronics        FESTIVE50                  64.30
# ...

# %% [markdown]
# ### 39. Check if TID column has duplicates.

# %%
df['TID'].duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 54995    False
# 54996    False
# 54997    False
# 54998    False
# 54999    False
# Name: TID, Length: 55000, dtype: bool

# %% [markdown]
# ### 40. Drop duplicate rows based on TID.

# %%
df.drop_duplicates(subset=['TID'], keep='first', inplace=True)
df[['TID']]
# Out:
#               TID
# 0      5876328741
# 1      1018503182
# 2      3814082218
# 3      1395204173
# 4      8009390577
# ...           ...
# 54995  5407639888
# 54996  1144029904
# 54997  9587323189
# 54998  5032564481
# 54999  9172953722
#
# [55000 rows x 1 columns]

# %% [markdown]
# ### 41. Convert Purchase Date to datetime format.

# %%
df['Purchase Date'] = pd.to_datetime(df['Purchase Date'],dayfirst=True)

# %% [markdown]
# ### 42. Convert CID to integer type (handle missing values first).

# %%
df['CID'] = df['CID'].fillna(0).astype(int)
df[['CID']]
# Out:
#           CID
# 0      943146
# 1      180079
# 2      337580
# 3      180333
# 4      447553
# ...       ...
# 54995  295864
# 54996  706435
# 54997  649435
# 54998  982183
# 54999  126691
#
# [55000 rows x 1 columns]

# %% [markdown]
# ### 43. Convert Discount Amount (INR) to float type.

# %%
df['Discount Amount (INR)'] = df['Discount Amount (INR)'].astype(float)
df['Discount Amount (INR)']
# Out:
# 0         64.30
# 1        175.19
# 2        211.54
# 3          0.00
# 4        439.92
#           ...
# 54995    110.89
# 54996    488.59
# 54997    417.63
# 54998    204.56
# 54999    380.81
# Name: Discount Amount (INR), Length: 55000, dtype: float64

# %% [markdown]
# ### 44. Convert Gross Amount and Net Amount to float type.

# %%
df[['Gross Amount', 'Net Amount']] = df[['Gross Amount', 'Net Amount']].astype(float)
df[['Gross Amount', 'Net Amount']]
# Out:
#        Gross Amount   Net Amount
# 0        725.304000   661.004000
# 1       4638.991875  4463.801875
# 2       1986.372575  1774.832575
# 3       5695.612650  5695.612650
# 4       2292.651500  1852.731500
# ...             ...          ...
# 54995   2819.907300  2709.017300
# 54996   3891.303900  3402.713900
# 54997   4094.687500  3677.057500
# 54998   3977.473500  3772.913500
# 54999   3703.581900  3322.771900
#
# [55000 rows x 2 columns]

# %% [markdown]
# ### 45. Convert Gender column to category type.

# %%
df['Gender'] = df['Gender'].astype('category')
df['Gender'].dtype
# Out:
# CategoricalDtype(categories=['Female', 'Male', 'Other'], ordered=False, categories_dtype=object)

# %% [markdown]
# ### 46. Convert Location column to category type.

# %%
df['Location'] = df['Location'].astype('category')
df['Location'].dtype
# Out:
# CategoricalDtype(categories=['Ahmedabad', 'Bangalore', 'Chennai', 'Dehradun', 'Delhi',
#                   'Hyderabad', 'Jaipur', 'Kolkata', 'Lucknow', 'Mumbai',
#                   'Other', 'Pune', 'Srinagar', 'Varanasi'],
# , ordered=False, categories_dtype=object)

# %% [markdown]
# ### 47. Check memory usage before and after converting categorical columns.

# %%
# Memory usage of entire DataFrame
print("Memory usage before conversion:")
print(df.memory_usage(deep=True))
print("Total:", df.memory_usage(deep=True).sum(), "bytes")
# Out:
# Memory usage before conversion:
# Index                        132
# CID                       440000
# TID                       440000
# Gender                     55270
# Age Group                2997101
# Purchase Date             440000
# Product Category         3328417
# Discount Name            2489840
# Discount Amount (INR)     440000
# Gross Amount              440000
# Net Amount                440000
# Purchase Method          3322398
# Location                   56340
# dtype: int64
# Total: 14889498 bytes

# %%
# Example: converting Gender and Age Group to category

categorical_cols = ['Gender', 'Age Group', 'Purchase Method', 'Location']
df[categorical_cols] = df[categorical_cols].astype('category')

# %%
print("\nMemory usage after conversion:")
print(df.memory_usage(deep=True))
print("Total:", df.memory_usage(deep=True).sum(), "bytes")
# Out:
# Memory usage after conversion:
# Index                        132
# CID                       440000
# TID                       440000
# Gender                     55270
# Age Group                  55452
# Purchase Date             440000
# Product Category         3328417
# Discount Name            2489840
# Discount Amount (INR)     440000
# Gross Amount              440000
# Net Amount                440000
# Purchase Method            55792
# Location                   56340
# dtype: int64
# Total: 8681243 bytes

# %% [markdown]
# ### 48. Extract the year from Purchase Date into a new column.

# %%
df['Year'] = df['Purchase Date'].dt.year
df[['Purchase Date', 'Year']].head()
# Out:
#         Purchase Date  Year
# 0 2023-08-30 20:27:08  2023
# 1 2024-02-23 09:33:46  2024
# 2 2022-03-06 09:09:50  2022
# 3 2020-11-04 04:41:57  2020
# 4 2022-05-31 17:00:32  2022

# %% [markdown]
# ### 49. Extract the month from Purchase Date into a new column.

# %%
df['Month'] = df['Purchase Date'].dt.month
df[['Purchase Date', 'Month']].head()
# Out:
#         Purchase Date  Month
# 0 2023-08-30 20:27:08      8
# 1 2024-02-23 09:33:46      2
# 2 2022-03-06 09:09:50      3
# 3 2020-11-04 04:41:57     11
# 4 2022-05-31 17:00:32      5

# %% [markdown]
# ### 50. Extract the day name from Purchase Date into a new column.

# %%
df['Day'] = df['Purchase Date'].dt.day
df[['Purchase Date', 'Day']].head()
# Out:
#         Purchase Date  Day
# 0 2023-08-30 20:27:08   30
# 1 2024-02-23 09:33:46   23
# 2 2022-03-06 09:09:50    6
# 3 2020-11-04 04:41:57    4
# 4 2022-05-31 17:00:32   31

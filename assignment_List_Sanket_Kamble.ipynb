# %% [markdown]
# # Basic List Operations

# %% [markdown]
# 1. Create a list of 5 numbers and add a new number to the end.

# %%
lst = [1,2,3,4,5]

lst.append(6)

lst
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# 2. Make a list of fruits and insert a fruit at the second position.

# %%
lst = ['mango','banana','guava','grapes','apple']

lst.insert(1,'strawberry')

lst
# Out:
# ['mango', 'strawberry', 'banana', 'guava', 'grapes', 'apple']

# %% [markdown]
# 3. Create a list of names and remove one name from the list.

# %%
lst = ['sanket','harsh','sanket','sujit','sagar']

lst.pop()
print("list after pop() : ",lst)

lst.remove('sujit')
print("after remove() : ",lst)
# Out:
# list after pop() :  ['sanket', 'harsh', 'sanket', 'sujit']
# after remove() :  ['sanket', 'harsh', 'sanket']

# %% [markdown]
# 4. Create a list of 4 items and change the value at index 2.

# %%
lst = ['table','tv','laptop','mobile']

lst[2] = 'headphones'
print(lst)
# Out:
# ['table', 'tv', 'headphones', 'mobile']

# %% [markdown]
# 5. Make a list of numbers and print only the first three elements.

# %%
num = [1,2,3,4,5,6,7]

num[0:3]
# Out:
# [1, 2, 3]

# %% [markdown]
# 6. Create a list of colors and find the index of a specific color.

# %%
colors = ['blue','red','violet','pink','white']

print("index of red is : ", colors.index('red'))
# Out:
# index of red is :  1

# %% [markdown]
# 7. Create a list of 10 numbers and print how many times “5” appears.

# %%
num = [1,3,4,5,4,5,7,5,8,5]

print("count of number 5 is : ",num.count(5))
# Out:
# count of number 5 is :  4

# %% [markdown]
# 8. Make a list of 6 items and delete the item at index 3.

# %%
lst = ['table','tv','laptop','mobile','headphones','camera']

lst.pop(3)
# Out:
# 'mobile'

# %% [markdown]
# 9. Create a list of animals and add three more animals using extend().

# %%
animal = ['rabbit','zebra','dog','cat','fox']

add_animal = ['tiger','goat','lion']

animal.extend(add_animal)

animal
# Out:
# ['rabbit', 'zebra', 'dog', 'cat', 'fox', 'tiger', 'goat', 'lion']

# %% [markdown]
# 10. Create a list and remove the last item using pop().

# %%
animal = ['rabbit','zebra','dog','cat','fox']

animal.pop()
# Out:
# 'fox'

# %% [markdown]
# 11. Create a list of prices and sort them in ascending order.

# %%
prices = [400,500,100,50,800,900]

prices.sort()

prices
# Out:
# [50, 100, 400, 500, 800, 900]

# %% [markdown]
# 12. Make a list of countries and reverse the order of the list.

# %%
country = ['india','africa','brazil','srilanka']

country.reverse()

country
# Out:
# ['srilanka', 'brazil', 'africa', 'india']

# %% [markdown]
# 13. Create a list of words and check if “apple” is in the list.

# %%
words = ['mango','banana','guava','grapes','apple']

words.count('apple')
# Out:
# 1

# %% [markdown]
# 14. Create a list of numbers and print the largest and smallest number.

# %%
num = [1,2,3,4,5,6,7,8,9]

print("largest number is : ",max(num))
print("smallest number is : ",min(num))
# Out:
# largest number is :  9
# smallest number is :  1

# %% [markdown]
# 15. Make a list of 5 items and print each item using a loop.

# %% [markdown]
# 16. Create two lists and combine them into one list.

# %%
lst1 = [1,2,3]
lst2 = [4,2,6]

lst1.extend(lst2)
lst1
# Out:
# [1, 2, 3, 4, 2, 6]

# %% [markdown]
# 17. Make a list and replace the last item with a new value.

# %%
lst = [1,2,3,4,5,6,7,8]

lst[-1] = 100
lst
# Out:
# [1, 2, 3, 4, 5, 6, 7, 100]

# %% [markdown]
# 18. Create a list of numbers and print only the even numbers.

# %%
lst = [1,2,3,4,5,6,7,8]

for num in lst :
    if num % 2 == 0:
        print(num)
# Out:
# 2
# 4
# 6
# 8

# %% [markdown]
# 19. Create a list and clear all items from the list.

# %%
lst = [1,2,3,4,5,6,7,8]

lst.clear()
lst
# Out:
# []

# %% [markdown]
# 20. Create a list of 5 values and copy it into another list.

# %%
lst = [1,2,3,4,5]

lst_copy = lst.copy()

lst_copy
# Out:
# [1, 2, 3, 4, 5]
